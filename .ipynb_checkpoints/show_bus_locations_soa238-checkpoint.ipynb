# %%
#importing libraries
import pylab as pl
import json
import csv
import urllib2 as urllib
import sys
import pandas as pd
import config

# %%
#Creating system arguments to run the code
if len(sys.argv) != 3:
    print("Invalid number of arguments run as: python get_bus_info_soa238.py <APIKEY> <Bus line>")
    sys.exit()

# %%
#identifying system arguments
key= sys.argv[1]
busline= sys.argv[2]

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key="+key+"&VehicleMonitoringDetailLevel=calls&LineRef="+busline

# %%
#pulling data from URL and reading them
rawdata = urllib.urlopen(url)
decodeddata = rawdata.read().decode("utf-8")
decodeddata = json.loads(decodeddata)
datapath = decodeddata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']

try:
    datapath=decodeddata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
except KeyError:
    datapath='N/A'
    
datapath
# Out:
# [{u'MonitoredVehicleJourney': {u'Bearing': 6.589333,
#    u'BlockRef': u'MTA NYCT_FP_D8-Weekday-SDon_E_FP_74880_B26-26',
#    u'DestinationName': u'RIDGEWOOD TERM via GATES',
#    u'DestinationRef': u'MTA_801117',
#    u'DirectionRef': u'0',
#    u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2018-09-28',
#     u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D8-Weekday-SDon-132100_B26_26'},
#    u'JourneyPatternRef': u'MTA_B520052',
#    u'LineRef': u'MTA NYCT_B52',
#    u'Monitored': True,
#    u'MonitoredCall': {u'ExpectedArrivalTime': u'2018-09-28T22:34:45.063-04:00',
#     u'ExpectedDepartureTime': u'2018-09-28T22:34:45.063-04:00',
#     u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6734.12,
#       u'DistanceFromCall': 3.68,
#       u'PresentableDistance': u'at stop',
#       u'StopsFromCall': 0}},
#     u'StopPointName': u'GATES AV/BROADWAY',
#     u'StopPointRef': u'MTA_307686',
#     u'VisitNumber': 1},
#    u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2018-09-28T22:34:44.063-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6734.12,
#         u'DistanceFromCall': 3.68,
#         u'PresentableDistance': u'at stop',
#         u'StopsFromCall': 0}},
#       u'StopPointName': u'GATES AV/BROADWAY',
#       u'StopPointRef': u'MTA_307686'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:35:59.930-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6977.66,
#         u'DistanceFromCall': 247.21,
#         u'PresentableDistance': u'1 stop away',
#         u'StopsFromCall': 1}},
#       u'StopPointName': u'GATES AV/BUSHWICK AV',
#       u'StopPointRef': u'MTA_307687'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:36:41.705-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7146.91,
#         u'DistanceFromCall': 416.46,
#         u'PresentableDistance': u'2 stops away',
#         u'StopsFromCall': 2}},
#       u'StopPointName': u'GATES AV/EVERGREEN AV',
#       u'StopPointRef': u'MTA_307688'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:37:38.303-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7388.47,
#         u'DistanceFromCall': 658.03,
#         u'PresentableDistance': u'3 stops away',
#         u'StopsFromCall': 3}},
#       u'StopPointName': u'GATES AV/CENTRAL AV',
#       u'StopPointRef': u'MTA_307689'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:38:34.661-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7591.7,
#         u'DistanceFromCall': 861.26,
#         u'PresentableDistance': u'0.5 miles away',
#         u'StopsFromCall': 4}},
#       u'StopPointName': u'GATES AV/WILSON AV',
#       u'StopPointRef': u'MTA_307690'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:39:32.802-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7797.59,
#         u'DistanceFromCall': 1067.14,
#         u'PresentableDistance': u'0.7 miles away',
#         u'StopsFromCall': 5}},
#       u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#       u'StopPointRef': u'MTA_307691'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:40:48.528-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8098.58,
#         u'DistanceFromCall': 1368.13,
#         u'PresentableDistance': u'0.9 miles away',
#         u'StopsFromCall': 6}},
#       u'StopPointName': u'PALMETTO ST/IRVING AV',
#       u'StopPointRef': u'MTA_304415'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:41:21.741-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8248.54,
#         u'DistanceFromCall': 1518.09,
#         u'PresentableDistance': u'0.9 miles away',
#         u'StopsFromCall': 7}},
#       u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#       u'StopPointRef': u'MTA_801117'}]},
#    u'OperatorRef': u'MTA NYCT',
#    u'OriginRef': u'MTA_307175',
#    u'ProgressRate': u'normalProgress',
#    u'PublishedLineName': u'B52',
#    u'SituationRef': [],
#    u'VehicleLocation': {u'Latitude': 40.689471, u'Longitude': -73.922266},
#    u'VehicleRef': u'MTA NYCT_3988'},
#   u'RecordedAtTime': u'2018-09-28T22:34:27.000-04:00'},
#  {u'MonitoredVehicleJourney': {u'Bearing': 6.3943977,
#    u'BlockRef': u'MTA NYCT_FP_D8-Weekday-SDon_E_FP_76080_B54-225',
#    u'DestinationName': u'RIDGEWOOD TERM via GATES',
#    u'DestinationRef': u'MTA_801117',
#    u'DirectionRef': u'0',
#    u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2018-09-28',
#     u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D8-Weekday-SDon-134000_B54_225'},
#    u'JourneyPatternRef': u'MTA_B520052',
#    u'LineRef': u'MTA NYCT_B52',
#    u'Monitored': True,
#    u'MonitoredCall': {u'ExpectedArrivalTime': u'2018-09-28T22:34:45.063-04:00',
#     u'ExpectedDepartureTime': u'2018-09-28T22:34:45.063-04:00',
#     u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3125.5,
#       u'DistanceFromCall': 10.92,
#       u'PresentableDistance': u'at stop',
#       u'StopsFromCall': 0}},
#     u'StopPointName': u'GREENE AV/GRAND AV',
#     u'StopPointRef': u'MTA_307551',
#     u'VisitNumber': 1},
#    u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2018-09-28T22:34:44.063-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3125.5,
#         u'DistanceFromCall': 10.92,
#         u'PresentableDistance': u'at stop',
#         u'StopsFromCall': 0}},
#       u'StopPointName': u'GREENE AV/GRAND AV',
#       u'StopPointRef': u'MTA_307551'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:35:19.516-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3364.21,
#         u'DistanceFromCall': 249.63,
#         u'PresentableDistance': u'1 stop away',
#         u'StopsFromCall': 1}},
#       u'StopPointName': u'GREENE AV/CLASSON AV',
#       u'StopPointRef': u'MTA_307552'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:36:22.716-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3595.03,
#         u'DistanceFromCall': 480.45,
#         u'PresentableDistance': u'2 stops away',
#         u'StopsFromCall': 2}},
#       u'StopPointName': u'FRANKLIN AV/GREENE AV',
#       u'StopPointRef': u'MTA_307553'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:37:26.116-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3843.44,
#         u'DistanceFromCall': 728.86,
#         u'PresentableDistance': u'3 stops away',
#         u'StopsFromCall': 3}},
#       u'StopPointName': u'GATES AV/FRANKLIN AV',
#       u'StopPointRef': u'MTA_307674'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:38:38.538-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4027.09,
#         u'DistanceFromCall': 912.51,
#         u'PresentableDistance': u'0.6 miles away',
#         u'StopsFromCall': 4}},
#       u'StopPointName': u'GATES AV/BEDFORD AV',
#       u'StopPointRef': u'MTA_307675'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:39:32.675-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4291.16,
#         u'DistanceFromCall': 1176.58,
#         u'PresentableDistance': u'0.7 miles away',
#         u'StopsFromCall': 5}},
#       u'StopPointName': u'GATES AV/NOSTRAND AV',
#       u'StopPointRef': u'MTA_307676'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:41:06.675-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4616.54,
#         u'DistanceFromCall': 1501.95,
#         u'PresentableDistance': u'0.9 miles away',
#         u'StopsFromCall': 6}},
#       u'StopPointName': u'GATES AV/MARCY AV',
#       u'StopPointRef': u'MTA_307677'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:42:10.875-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4866.0,
#         u'DistanceFromCall': 1751.42,
#         u'PresentableDistance': u'1.1 miles away',
#         u'StopsFromCall': 7}},
#       u'StopPointName': u'GATES AV/TOMPKINS AV',
#       u'StopPointRef': u'MTA_307678'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:43:15.475-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5103.34,
#         u'DistanceFromCall': 1988.76,
#         u'PresentableDistance': u'1.2 miles away',
#         u'StopsFromCall': 8}},
#       u'StopPointName': u'GATES AV/THROOP AV',
#       u'StopPointRef': u'MTA_307679'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:44:18.675-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5342.21,
#         u'DistanceFromCall': 2227.63,
#         u'PresentableDistance': u'1.4 miles away',
#         u'StopsFromCall': 9}},
#       u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#       u'StopPointRef': u'MTA_307680'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:45:42.730-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5591.01,
#         u'DistanceFromCall': 2476.42,
#         u'PresentableDistance': u'1.5 miles away',
#         u'StopsFromCall': 10}},
#       u'StopPointName': u'GATES AV/LEWIS AV',
#       u'StopPointRef': u'MTA_307681'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:46:58.328-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5842.65,
#         u'DistanceFromCall': 2728.07,
#         u'PresentableDistance': u'1.7 miles away',
#         u'StopsFromCall': 11}},
#       u'StopPointName': u'GATES AV/STUYVESANT AV',
#       u'StopPointRef': u'MTA_307682'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:48:27.928-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6092.05,
#         u'DistanceFromCall': 2977.46,
#         u'PresentableDistance': u'1.9 miles away',
#         u'StopsFromCall': 12}},
#       u'StopPointName': u'GATES AV/MALCOLM X BL',
#       u'StopPointRef': u'MTA_307683'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:49:28.586-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6337.9,
#         u'DistanceFromCall': 3223.31,
#         u'PresentableDistance': u'2.0 miles away',
#         u'StopsFromCall': 13}},
#       u'StopPointName': u'GATES AV/PATCHEN AV',
#       u'StopPointRef': u'MTA_307684'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:50:26.865-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6572.3,
#         u'DistanceFromCall': 3457.72,
#         u'PresentableDistance': u'2.1 miles away',
#         u'StopsFromCall': 14}},
#       u'StopPointName': u'GATES AV/RALPH AV',
#       u'StopPointRef': u'MTA_307901'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:51:18.465-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6734.12,
#         u'DistanceFromCall': 3619.54,
#         u'PresentableDistance': u'2.2 miles away',
#         u'StopsFromCall': 15}},
#       u'StopPointName': u'GATES AV/BROADWAY',
#       u'StopPointRef': u'MTA_307686'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:52:50.223-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6977.66,
#         u'DistanceFromCall': 3863.07,
#         u'PresentableDistance': u'2.4 miles away',
#         u'StopsFromCall': 16}},
#       u'StopPointName': u'GATES AV/BUSHWICK AV',
#       u'StopPointRef': u'MTA_307687'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:53:31.998-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7146.91,
#         u'DistanceFromCall': 4032.32,
#         u'PresentableDistance': u'2.5 miles away',
#         u'StopsFromCall': 17}},
#       u'StopPointName': u'GATES AV/EVERGREEN AV',
#       u'StopPointRef': u'MTA_307688'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:54:28.596-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7388.47,
#         u'DistanceFromCall': 4273.89,
#         u'PresentableDistance': u'2.7 miles away',
#         u'StopsFromCall': 18}},
#       u'StopPointName': u'GATES AV/CENTRAL AV',
#       u'StopPointRef': u'MTA_307689'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:55:24.954-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7591.7,
#         u'DistanceFromCall': 4477.12,
#         u'PresentableDistance': u'2.8 miles away',
#         u'StopsFromCall': 19}},
#       u'StopPointName': u'GATES AV/WILSON AV',
#       u'StopPointRef': u'MTA_307690'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:56:23.095-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7797.59,
#         u'DistanceFromCall': 4683.0,
#         u'PresentableDistance': u'2.9 miles away',
#         u'StopsFromCall': 20}},
#       u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#       u'StopPointRef': u'MTA_307691'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:57:38.821-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8098.58,
#         u'DistanceFromCall': 4984.0,
#         u'PresentableDistance': u'3.1 miles away',
#         u'StopsFromCall': 21}},
#       u'StopPointName': u'PALMETTO ST/IRVING AV',
#       u'StopPointRef': u'MTA_304415'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:58:12.034-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8248.54,
#         u'DistanceFromCall': 5133.96,
#         u'PresentableDistance': u'3.2 miles away',
#         u'StopsFromCall': 22}},
#       u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#       u'StopPointRef': u'MTA_801117'}]},
#    u'OperatorRef': u'MTA NYCT',
#    u'OriginRef': u'MTA_307175',
#    u'ProgressRate': u'normalProgress',
#    u'PublishedLineName': u'B52',
#    u'SituationRef': [],
#    u'VehicleLocation': {u'Latitude': 40.68711, u'Longitude': -73.962213},
#    u'VehicleRef': u'MTA NYCT_7268'},
#   u'RecordedAtTime': u'2018-09-28T22:34:16.000-04:00'},
#  {u'MonitoredVehicleJourney': {u'Bearing': 186.83504,
#    u'BlockRef': u'MTA NYCT_FP_D8-Weekday-SDon_E_FP_79800_B54-222',
#    u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#    u'DestinationRef': u'MTA_901463',
#    u'DirectionRef': u'1',
#    u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2018-09-28',
#     u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D8-Weekday-SDon-134000_B54_222'},
#    u'JourneyPatternRef': u'MTA_B520053',
#    u'LineRef': u'MTA NYCT_B52',
#    u'Monitored': True,
#    u'MonitoredCall': {u'ExpectedArrivalTime': u'2018-09-28T22:34:48.522-04:00',
#     u'ExpectedDepartureTime': u'2018-09-28T22:34:48.522-04:00',
#     u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3179.52,
#       u'DistanceFromCall': 50.47,
#       u'PresentableDistance': u'approaching',
#       u'StopsFromCall': 0}},
#     u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#     u'StopPointRef': u'MTA_306530',
#     u'VisitNumber': 1},
#    u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2018-09-28T22:34:48.522-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3179.52,
#         u'DistanceFromCall': 50.47,
#         u'PresentableDistance': u'approaching',
#         u'StopsFromCall': 0}},
#       u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#       u'StopPointRef': u'MTA_306530'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:35:46.795-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3373.21,
#         u'DistanceFromCall': 244.17,
#         u'PresentableDistance': u'1 stop away',
#         u'StopsFromCall': 1}},
#       u'StopPointName': u'GATES AV/THROOP AV',
#       u'StopPointRef': u'MTA_304209'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:37:20.195-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3659.6,
#         u'DistanceFromCall': 530.55,
#         u'PresentableDistance': u'2 stops away',
#         u'StopsFromCall': 2}},
#       u'StopPointName': u'GATES AV/TOMPKINS AV',
#       u'StopPointRef': u'MTA_304210'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:39:02.595-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3903.29,
#         u'DistanceFromCall': 774.24,
#         u'PresentableDistance': u'3 stops away',
#         u'StopsFromCall': 3}},
#       u'StopPointName': u'GATES AV/MARCY AV',
#       u'StopPointRef': u'MTA_304211'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:40:42.723-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4183.96,
#         u'DistanceFromCall': 1054.92,
#         u'PresentableDistance': u'0.7 miles away',
#         u'StopsFromCall': 4}},
#       u'StopPointName': u'GATES AV/NOSTRAND AV',
#       u'StopPointRef': u'MTA_304212'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:41:52.796-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4497.03,
#         u'DistanceFromCall': 1367.99,
#         u'PresentableDistance': u'0.9 miles away',
#         u'StopsFromCall': 5}},
#       u'StopPointName': u'GATES AV/BEDFORD AV',
#       u'StopPointRef': u'MTA_304213'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:42:56.189-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4676.87,
#         u'DistanceFromCall': 1547.83,
#         u'PresentableDistance': u'1.0 miles away',
#         u'StopsFromCall': 6}},
#       u'StopPointName': u'GATES AV/FRANKLIN AV',
#       u'StopPointRef': u'MTA_304214'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:43:36.989-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.43,
#         u'DistanceFromCall': 1735.39,
#         u'PresentableDistance': u'1.1 miles away',
#         u'StopsFromCall': 7}},
#       u'StopPointName': u'GATES AV/CLASSON AV',
#       u'StopPointRef': u'MTA_307948'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:45:10.589-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.07,
#         u'DistanceFromCall': 2027.03,
#         u'PresentableDistance': u'1.3 miles away',
#         u'StopsFromCall': 8}},
#       u'StopPointName': u'GREENE AV/CLASSON AV',
#       u'StopPointRef': u'MTA_307572'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:45:58.036-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5397.42,
#         u'DistanceFromCall': 2268.38,
#         u'PresentableDistance': u'1.4 miles away',
#         u'StopsFromCall': 9}},
#       u'StopPointName': u'GREENE AV/GRAND AV',
#       u'StopPointRef': u'MTA_307573'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:47:05.094-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5655.77,
#         u'DistanceFromCall': 2526.73,
#         u'PresentableDistance': u'1.6 miles away',
#         u'StopsFromCall': 10}},
#       u'StopPointName': u'GREENE AV/WASHINGTON AV',
#       u'StopPointRef': u'MTA_307596'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:48:11.385-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5907.49,
#         u'DistanceFromCall': 2778.45,
#         u'PresentableDistance': u'1.7 miles away',
#         u'StopsFromCall': 11}},
#       u'StopPointName': u'GREENE AV/VANDERBILT AV',
#       u'StopPointRef': u'MTA_307575'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:48:54.615-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6074.28,
#         u'DistanceFromCall': 2945.24,
#         u'PresentableDistance': u'1.8 miles away',
#         u'StopsFromCall': 12}},
#       u'StopPointName': u'GREENE AV/ADELPHI ST',
#       u'StopPointRef': u'MTA_307576'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:49:46.080-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6238.78,
#         u'DistanceFromCall': 3109.74,
#         u'PresentableDistance': u'1.9 miles away',
#         u'StopsFromCall': 13}},
#       u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#       u'StopPointRef': u'MTA_307577'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:51:05.844-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6487.03,
#         u'DistanceFromCall': 3357.99,
#         u'PresentableDistance': u'2.1 miles away',
#         u'StopsFromCall': 14}},
#       u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#       u'StopPointRef': u'MTA_302427'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:51:37.333-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6642.98,
#         u'DistanceFromCall': 3513.93,
#         u'PresentableDistance': u'2.2 miles away',
#         u'StopsFromCall': 15}},
#       u'StopPointName': u'FULTON ST/FT GREENE PL',
#       u'StopPointRef': u'MTA_302428'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:53:09.333-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6942.37,
#         u'DistanceFromCall': 3813.33,
#         u'PresentableDistance': u'2.4 miles away',
#         u'StopsFromCall': 16}},
#       u'StopPointName': u'FULTON ST/HUDSON AV',
#       u'StopPointRef': u'MTA_302430'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:54:38.796-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7193.37,
#         u'DistanceFromCall': 4064.33,
#         u'PresentableDistance': u'2.5 miles away',
#         u'StopsFromCall': 17}},
#       u'StopPointName': u'FULTON ST/BOND ST',
#       u'StopPointRef': u'MTA_302431'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:55:40.692-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7397.6,
#         u'DistanceFromCall': 4268.56,
#         u'PresentableDistance': u'2.7 miles away',
#         u'StopsFromCall': 18}},
#       u'StopPointName': u'FULTON ST/DUFFIELD ST',
#       u'StopPointRef': u'MTA_307492'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:56:29.626-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7605.4,
#         u'DistanceFromCall': 4476.36,
#         u'PresentableDistance': u'2.8 miles away',
#         u'StopsFromCall': 19}},
#       u'StopPointName': u'FULTON ST/JAY ST',
#       u'StopPointRef': u'MTA_302433'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:58:22.298-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7931.22,
#         u'DistanceFromCall': 4802.17,
#         u'PresentableDistance': u'3.0 miles away',
#         u'StopsFromCall': 20}},
#       u'StopPointName': u'JORALEMON ST/COURT ST',
#       u'StopPointRef': u'MTA_302434'},
#      {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8065.26,
#         u'DistanceFromCall': 4936.22,
#         u'PresentableDistance': u'3.1 miles away',
#         u'StopsFromCall': 21}},
#       u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#       u'StopPointRef': u'MTA_306533'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:59:20.309-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8096.35,
#         u'DistanceFromCall': 4967.31,
#         u'PresentableDistance': u'3.1 miles away',
#         u'StopsFromCall': 22}},
#       u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#       u'StopPointRef': u'MTA_901463'}]},
#    u'OperatorRef': u'MTA NYCT',
#    u'OriginRef': u'MTA_504965',
#    u'ProgressRate': u'normalProgress',
#    u'PublishedLineName': u'B52',
#    u'SituationRef': [],
#    u'VehicleLocation': {u'Latitude': 40.687541, u'Longitude': -73.938783},
#    u'VehicleRef': u'MTA NYCT_6508'},
#   u'RecordedAtTime': u'2018-09-28T22:34:28.000-04:00'},
#  {u'MonitoredVehicleJourney': {u'Bearing': 105.888695,
#    u'BlockRef': u'MTA NYCT_FP_D8-Weekday-SDon_E_FP_19200_B52-105',
#    u'DestinationName': u'RIDGEWOOD TERM via GATES',
#    u'DestinationRef': u'MTA_801117',
#    u'DirectionRef': u'0',
#    u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2018-09-28',
#     u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D8-Weekday-SDon-136000_B52_133'},
#    u'JourneyPatternRef': u'MTA_B520052',
#    u'LineRef': u'MTA NYCT_B52',
#    u'Monitored': True,
#    u'MonitoredCall': {u'ExpectedArrivalTime': u'2018-09-28T22:34:56.430-04:00',
#     u'ExpectedDepartureTime': u'2018-09-28T22:34:56.430-04:00',
#     u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 175.45,
#       u'DistanceFromCall': 171.79,
#       u'PresentableDistance': u'< 1 stop away',
#       u'StopsFromCall': 0}},
#     u'StopPointName': u'Tillary St (not used)',
#     u'StopPointRef': u'MTA_801145',
#     u'VisitNumber': 1},
#    u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2018-09-28T22:34:56.430-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 175.45,
#         u'DistanceFromCall': 171.79,
#         u'PresentableDistance': u'< 1 stop away',
#         u'StopsFromCall': 0}},
#       u'StopPointName': u'Tillary St (not used)',
#       u'StopPointRef': u'MTA_801145'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:37:24.118-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 610.65,
#         u'DistanceFromCall': 606.99,
#         u'PresentableDistance': u'1 stop away',
#         u'StopsFromCall': 1}},
#       u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#       u'StopPointRef': u'MTA_307460'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:39:21.518-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 810.21,
#         u'DistanceFromCall': 806.54,
#         u'PresentableDistance': u'0.5 miles away',
#         u'StopsFromCall': 2}},
#       u'StopPointName': u'FULTON ST/SMITH ST',
#       u'StopPointRef': u'MTA_302945'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:40:48.918-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 999.31,
#         u'DistanceFromCall': 995.65,
#         u'PresentableDistance': u'0.6 miles away',
#         u'StopsFromCall': 3}},
#       u'StopPointName': u'FULTON ST/HOYT ST',
#       u'StopPointRef': u'MTA_307491'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:42:22.518-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1233.08,
#         u'DistanceFromCall': 1229.42,
#         u'PresentableDistance': u'0.8 miles away',
#         u'StopsFromCall': 4}},
#       u'StopPointName': u'FULTON ST/BOND ST',
#       u'StopPointRef': u'MTA_302947'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:43:26.118-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1406.74,
#         u'DistanceFromCall': 1403.08,
#         u'PresentableDistance': u'0.9 miles away',
#         u'StopsFromCall': 5}},
#       u'StopPointName': u'FULTON ST/FLATBUSH AV EXT',
#       u'StopPointRef': u'MTA_302948'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:45:05.435-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1696.87,
#         u'DistanceFromCall': 1693.21,
#         u'PresentableDistance': u'1.1 miles away',
#         u'StopsFromCall': 6}},
#       u'StopPointName': u'FULTON ST/ASHLAND PL',
#       u'StopPointRef': u'MTA_303017'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:45:41.742-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1844.07,
#         u'DistanceFromCall': 1840.41,
#         u'PresentableDistance': u'1.1 miles away',
#         u'StopsFromCall': 7}},
#       u'StopPointName': u'FULTON ST/LAFAYETTE AV',
#       u'StopPointRef': u'MTA_302368'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:47:41.342-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2098.42,
#         u'DistanceFromCall': 2094.75,
#         u'PresentableDistance': u'1.3 miles away',
#         u'StopsFromCall': 8}},
#       u'StopPointName': u'FULTON ST/S PORTLAND AV',
#       u'StopPointRef': u'MTA_302369'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:48:34.000-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2232.18,
#         u'DistanceFromCall': 2228.52,
#         u'PresentableDistance': u'1.4 miles away',
#         u'StopsFromCall': 9}},
#       u'StopPointName': u'GREENE AV/FULTON ST',
#       u'StopPointRef': u'MTA_307547'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:49:32.170-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2445.5,
#         u'DistanceFromCall': 2441.84,
#         u'PresentableDistance': u'1.5 miles away',
#         u'StopsFromCall': 10}},
#       u'StopPointName': u'GREENE AV/ADELPHI ST',
#       u'StopPointRef': u'MTA_307548'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:50:26.153-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2617.34,
#         u'DistanceFromCall': 2613.67,
#         u'PresentableDistance': u'1.6 miles away',
#         u'StopsFromCall': 11}},
#       u'StopPointName': u'GREENE AV/VANDERBILT AV',
#       u'StopPointRef': u'MTA_307549'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:51:37.008-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2867.09,
#         u'DistanceFromCall': 2863.43,
#         u'PresentableDistance': u'1.8 miles away',
#         u'StopsFromCall': 12}},
#       u'StopPointName': u'GREENE AV/WASHINGTON AV',
#       u'StopPointRef': u'MTA_307550'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:52:42.008-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3125.5,
#         u'DistanceFromCall': 3121.84,
#         u'PresentableDistance': u'1.9 miles away',
#         u'StopsFromCall': 13}},
#       u'StopPointName': u'GREENE AV/GRAND AV',
#       u'StopPointRef': u'MTA_307551'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:53:42.778-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3364.21,
#         u'DistanceFromCall': 3360.55,
#         u'PresentableDistance': u'2.1 miles away',
#         u'StopsFromCall': 14}},
#       u'StopPointName': u'GREENE AV/CLASSON AV',
#       u'StopPointRef': u'MTA_307552'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:54:45.978-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3595.03,
#         u'DistanceFromCall': 3591.36,
#         u'PresentableDistance': u'2.2 miles away',
#         u'StopsFromCall': 15}},
#       u'StopPointName': u'FRANKLIN AV/GREENE AV',
#       u'StopPointRef': u'MTA_307553'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:55:49.378-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3843.44,
#         u'DistanceFromCall': 3839.77,
#         u'PresentableDistance': u'2.4 miles away',
#         u'StopsFromCall': 16}},
#       u'StopPointName': u'GATES AV/FRANKLIN AV',
#       u'StopPointRef': u'MTA_307674'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:57:01.800-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4027.09,
#         u'DistanceFromCall': 4023.42,
#         u'PresentableDistance': u'2.5 miles away',
#         u'StopsFromCall': 17}},
#       u'StopPointName': u'GATES AV/BEDFORD AV',
#       u'StopPointRef': u'MTA_307675'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:57:55.937-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4291.16,
#         u'DistanceFromCall': 4287.5,
#         u'PresentableDistance': u'2.7 miles away',
#         u'StopsFromCall': 18}},
#       u'StopPointName': u'GATES AV/NOSTRAND AV',
#       u'StopPointRef': u'MTA_307676'},
#      {u'ExpectedArrivalTime': u'2018-09-28T22:59:29.937-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4616.54,
#         u'DistanceFromCall': 4612.87,
#         u'PresentableDistance': u'2.9 miles away',
#         u'StopsFromCall': 19}},
#       u'StopPointName': u'GATES AV/MARCY AV',
#       u'StopPointRef': u'MTA_307677'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:00:34.137-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4866.0,
#         u'DistanceFromCall': 4862.33,
#         u'PresentableDistance': u'3.0 miles away',
#         u'StopsFromCall': 20}},
#       u'StopPointName': u'GATES AV/TOMPKINS AV',
#       u'StopPointRef': u'MTA_307678'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:01:38.737-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5103.34,
#         u'DistanceFromCall': 5099.67,
#         u'PresentableDistance': u'3.2 miles away',
#         u'StopsFromCall': 21}},
#       u'StopPointName': u'GATES AV/THROOP AV',
#       u'StopPointRef': u'MTA_307679'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:02:41.937-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5342.21,
#         u'DistanceFromCall': 5338.54,
#         u'PresentableDistance': u'3.3 miles away',
#         u'StopsFromCall': 22}},
#       u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#       u'StopPointRef': u'MTA_307680'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:04:05.992-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5591.01,
#         u'DistanceFromCall': 5587.34,
#         u'PresentableDistance': u'3.5 miles away',
#         u'StopsFromCall': 23}},
#       u'StopPointName': u'GATES AV/LEWIS AV',
#       u'StopPointRef': u'MTA_307681'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:05:21.590-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5842.65,
#         u'DistanceFromCall': 5838.98,
#         u'PresentableDistance': u'3.6 miles away',
#         u'StopsFromCall': 24}},
#       u'StopPointName': u'GATES AV/STUYVESANT AV',
#       u'StopPointRef': u'MTA_307682'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:06:51.190-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6092.05,
#         u'DistanceFromCall': 6088.38,
#         u'PresentableDistance': u'3.8 miles away',
#         u'StopsFromCall': 25}},
#       u'StopPointName': u'GATES AV/MALCOLM X BL',
#       u'StopPointRef': u'MTA_307683'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:07:51.848-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6337.9,
#         u'DistanceFromCall': 6334.23,
#         u'PresentableDistance': u'3.9 miles away',
#         u'StopsFromCall': 26}},
#       u'StopPointName': u'GATES AV/PATCHEN AV',
#       u'StopPointRef': u'MTA_307684'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:08:50.127-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6572.3,
#         u'DistanceFromCall': 6568.64,
#         u'PresentableDistance': u'4.1 miles away',
#         u'StopsFromCall': 27}},
#       u'StopPointName': u'GATES AV/RALPH AV',
#       u'StopPointRef': u'MTA_307901'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:09:41.727-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6734.12,
#         u'DistanceFromCall': 6730.46,
#         u'PresentableDistance': u'4.2 miles away',
#         u'StopsFromCall': 28}},
#       u'StopPointName': u'GATES AV/BROADWAY',
#       u'StopPointRef': u'MTA_307686'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:11:13.485-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6977.66,
#         u'DistanceFromCall': 6973.99,
#         u'PresentableDistance': u'4.3 miles away',
#         u'StopsFromCall': 29}},
#       u'StopPointName': u'GATES AV/BUSHWICK AV',
#       u'StopPointRef': u'MTA_307687'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:11:55.260-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7146.91,
#         u'DistanceFromCall': 7143.24,
#         u'PresentableDistance': u'4.4 miles away',
#         u'StopsFromCall': 30}},
#       u'StopPointName': u'GATES AV/EVERGREEN AV',
#       u'StopPointRef': u'MTA_307688'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:12:51.858-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7388.47,
#         u'DistanceFromCall': 7384.81,
#         u'PresentableDistance': u'4.6 miles away',
#         u'StopsFromCall': 31}},
#       u'StopPointName': u'GATES AV/CENTRAL AV',
#       u'StopPointRef': u'MTA_307689'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:13:48.216-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7591.7,
#         u'DistanceFromCall': 7588.03,
#         u'PresentableDistance': u'4.7 miles away',
#         u'StopsFromCall': 32}},
#       u'StopPointName': u'GATES AV/WILSON AV',
#       u'StopPointRef': u'MTA_307690'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:14:46.357-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7797.59,
#         u'DistanceFromCall': 7793.92,
#         u'PresentableDistance': u'4.8 miles away',
#         u'StopsFromCall': 33}},
#       u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#       u'StopPointRef': u'MTA_307691'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:16:02.083-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8098.58,
#         u'DistanceFromCall': 8094.91,
#         u'PresentableDistance': u'5.0 miles away',
#         u'StopsFromCall': 34}},
#       u'StopPointName': u'PALMETTO ST/IRVING AV',
#       u'StopPointRef': u'MTA_304415'},
#      {u'ExpectedArrivalTime': u'2018-09-28T23:16:35.296-04:00',
#       u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8248.54,
#         u'DistanceFromCall': 8244.87,
#         u'PresentableDistance': u'5.1 miles away',
#         u'StopsFromCall': 35}},
#       u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#       u'StopPointRef': u'MTA_801117'}]},
#    u'OperatorRef': u'MTA NYCT',
#    u'OriginRef': u'MTA_307175',
#    u'ProgressRate': u'normalProgress',
#    u'PublishedLineName': u'B52',
#    u'SituationRef': [],
#    u'VehicleLocation': {u'Latitude': 40.696007, u'Longitude': -73.991092},
#    u'VehicleRef': u'MTA NYCT_6496'},
#   u'RecordedAtTime': u'2018-09-28T22:34:41.000-04:00'}]

# %%
print (datapath[0]['MonitoredVehicleJourney']['PublishedLineName'])
loop = 0
for busdata in datapath:
    busdata=busdata['MonitoredVehicleJourney']
    print ('Bus',loop, 'is at latitude', busdata['VehicleLocation']['Latitude'],'&longitude',busdata['VehicleLocation']['Longitude'])
    loop+=1
# Out:
# B52
# ('Bus', 0, 'is at latitude', 40.689471, '&longitude', -73.922266)
# ('Bus', 1, 'is at latitude', 40.68711, '&longitude', -73.962213)
# ('Bus', 2, 'is at latitude', 40.687541, '&longitude', -73.938783)
# ('Bus', 3, 'is at latitude', 40.696007, '&longitude', -73.991092)
